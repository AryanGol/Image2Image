# %% [markdown]
# # Image2Image Colab
# This Colab notebook demonstrates how to run the Image2Image demo in Google Colab. Replace any placeholder URLs or commands with the actual ones from the repository (weights URL, demo command, etc.).

# %%
# 1) Install dependencies
# If your repository has a requirements.txt, it will be used. Adjust as necessary.
# !pip install -r requirements.txt || true
# If the project needs to be installed in editable mode:
# !pip install -e . || true

# %%
# 2) (Optional) Mount Google Drive to load or save models/data
# from google.colab import drive
# drive.mount('/content/drive')

# 3) Download pretrained weights (replace the URL below with a real one)
# !wget -O model.pth 'REPLACE_WITH_WEIGHTS_URL' || echo 'Please replace REPLACE_WITH_WEIGHTS_URL with the real download link'

# %%
# 4) Run the demo/inference. Replace the example command with the real script/arguments in this repository.
# !python demo.py --input sample.jpg --output out.jpg --weights model.pth || echo 'Adjust the demo command to match your repository scripts'

# %%
# 5) Show the output image (if produced)
from IPython.display import Image, display
try:
  display(Image('out.jpg'))
except Exception as e:
  print('Output not found or could not display:', e)
